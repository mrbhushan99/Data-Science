# %%
a= "Python"
a[2:5:1]
# Out:
# 'tho'

# %%
a[0:5:2]
# Out:
# 'Pto'

# %%
a[5:1:-1]
# Out:
# 'noht'

# %%
b="Monty python's flying circus"

# %%
b[0:5]
# Out:
# 'Monty'

# %%
b[0:3]
# Out:
# 'Mon'

# %%
b
# Out:
# "Monty python's flying circus"

# %%
b[3:10:2]
# Out:
# 't yh'

# %%
b[6:10:3]
# Out:
# 'ph'

# %%
b
# Out:
# "Monty python's flying circus"

# %%
b[15:18]
# Out:
# 'fly'

# %%
b
# Out:
# "Monty python's flying circus"

# %%
b[22:26:3]
# Out:
# 'cc'

# %%
b
# Out:
# "Monty python's flying circus"

# %%
# cir
b[22:25]
# Out:
# 'cir'

# %%
# mp
b[0:13:6]
# Out:
# "Mp'"

# %%
b
# Out:
# "Monty python's flying circus"

# %%
b[0:5] + 13
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 b[0:5] + 13
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Exercise

# %%
a="abcdefghijklmnopqrstuvwxyz"
#1. Extract every 3rd character starting from index 2
a[2::3]
# Out:
# 'cfilorux'

# %%
#2. Extract characters from index 20 to 5 using slicing
a[20:5:-1]
# Out:
# 'utsrqponmlkjihg'

# %%
#3. Reverse only characters between index 5 and 20
b=a[5:20:]
b[::-1]
# Out:
# 'tsrqponmlkjihgf'

# %%
#4. Extract alternate characters from the second half
a[13::2]
# Out:
# 'nprtvxz'

# %%
#5. Remove first 5 and last 5 characters, then reverse the result
c= a[:6]
d= a[21:]
e=c+d
e[::-1]
# Out:
# 'zyxwvfedcba'

# %%
# string 2

# %%
f="pythonprogramminglanguage"
#6. Reverse only "programming"
f[17:5:-1]
# Out:
# 'lgnimmargorp'

# %%
#7. Extract "python" using negative indexes only
len(f)
f[5::-1]
# Out:
# 'nohtyp'

# %%
f
# Out:
# 'pythonprogramminglanguage'

# %%
#8. Extract "language" using slicing without counting indexes
f[len(f)-8:]
#or
start_language_index=f.find("language")
end_index=len(f)
e=start_language_index+end_index
# Out:
# 42

# %%
#9. Reverse the string but keep "python" in correct order
g=f[:6]
g
# Out:
# 'python'
