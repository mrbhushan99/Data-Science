# %%
# type casting

# %%
a= 10 
print(int(a))
# Out:
# 10

# %%
float(a)
# Out:
# 10.0

# %%
complex(a)
# Out:
# (10+0j)

# %%
str(a)
# Out:
# '10'

# %%
list(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 list(a)
#
# TypeError: 'int' object is not iterable

# %%
tuple(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 tuple(a)
#
# TypeError: 'int' object is not iterable

# %%
set(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 set(a)
#
# TypeError: 'int' object is not iterable

# %%
dict(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 dict(a)
#
# TypeError: 'int' object is not iterable

# %%
# float to other

# %%
f=10.4

# %%
int(f)
# Out:
# 10

# %%
float(f)
# Out:
# 10.4

# %%
str(f)
# Out:
# '10.4'

# %%
list(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 list(f)
#
# TypeError: 'float' object is not iterable

# %%
tuple(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 tuple(f)
#
# TypeError: 'float' object is not iterable

# %%
set(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 set(f)
#
# TypeError: 'float' object is not iterable

# %%
dict(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 dict(f)
#
# TypeError: 'float' object is not iterable

# %%
# complex to other dtyaes 

c=10+5j

# %%
int(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 int(c)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
float(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 float(c)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
complex(c)
# Out:
# (10+5j)

# %%
bool(c)
# Out:
# True

# %%
str(c)
# Out:
# '(10+5j)'

# %%
list(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 list(c)
#
# TypeError: 'complex' object is not iterable

# %%
set(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 set(c)
#
# TypeError: 'complex' object is not iterable

# %%
tuple(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 tuple(c)
#
# TypeError: 'complex' object is not iterable

# %%
dict(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 dict(c)
#
# TypeError: 'complex' object is not iterable

# %%
# Out:
# (10+5j)

# %%
# boolean to other

# %%
a=True

# %%
bool (a)
# Out:
# True

# %%
int(a)
# Out:
# 1

# %%
float(a)
# Out:
# 1.0

# %%
str(a)
# Out:
# 'True'

# %%
list(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 list(a)
#
# TypeError: 'bool' object is not iterable

# %%
set(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 set(a)
#
# TypeError: 'bool' object is not iterable

# %%
tuple(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 tuple(a)
#
# TypeError: 'bool' object is not iterable

# %%
dict(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 dict(a)
#
# TypeError: 'bool' object is not iterable

# %%
#Multialue Datatypes to other

# %%
s="sam"

# %%
int(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 int(s)
#
# ValueError: invalid literal for int() with base 10: 'sam'

# %%
flaot(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 flaot(s)
#
# NameError: name 'flaot' is not defined

# %%
bool(s)
# Out:
# True

# %%
complex(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 complex(s)
#
# ValueError: complex() arg is a malformed string

# %%
list(s)
# Out:
# ['s', 'a', 'm']

# %%
set(s)
# Out:
# {'a', 'm', 's'}

# %%
dict(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 dict(s)
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %%
# list to other datatypes conversion

# %%
l = [10,True,12.3]

# %%
int(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 int(l)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'list'

# %%
float(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 float(l)
#
# TypeError: float() argument must be a string or a real number, not 'list'

# %%
complex(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 complex(l)
#
# TypeError: complex() first argument must be a string or a number, not 'list'

# %%
bool(l)
# Out:
# True

# %%
str(l)
# Out:
# '[10, True, 12.3]'

# %%
list(l)
# Out:
# [10, True, 12.3]

# %%
tuple(l)
# Out:
# (10, True, 12.3)

# %%
set(l)
# Out:
# {True, 10, 12.3}

# %%
dict(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 dict(l)
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
# Tuple to other

# %%
t=("a",15,True)
int(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 2
#       1 t=("a",15,True)
# ----> 2 int(t)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'tuple'

# %%
float(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 float(t)
#
# TypeError: float() argument must be a string or a real number, not 'tuple'

# %%
complex(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 complex(t)
#
# TypeError: complex() first argument must be a string or a number, not 'tuple'

# %%
str(t)
# Out:
# "('a', 15, True)"

# %%
list(t)
# Out:
# ['a', 15, True]

# %%
tuple(t)
# Out:
# ('a', 15, True)

# %%
t
# Out:
# ('a', 15, True)

# %%
set(t) # i have some doubt
# Out:
# {15, True, 'a'}

# %%
dict(t)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 dict(t)
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %%
#set to other

# %%
s={10,True,"abc"}

# %%
# dict to other

# %%
d = {"Name":"Bhushan","age":21}

# %%
int(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 int(d)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'dict'

# %%
float(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 float(d)
#
# TypeError: float() argument must be a string or a real number, not 'dict'

# %%
complex(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 complex(d)
#
# TypeError: complex() first argument must be a string or a number, not 'dict'

# %%
str(d)
# Out:
# "{'Name': 'Bhushan', 'age': 21}"

# %%
list(d) # only keys are converting to list here
# Out:
# ['Name', 'age']

# %%
tuple(d)
# Out:
# ('Name', 'age')

# %%
set(d)
# Out:
# {'Name', 'age'}

# %%
dict(d)
# Out:
# {'Name': 'Bhushan', 'age': 21}
