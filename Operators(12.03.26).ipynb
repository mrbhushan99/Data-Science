# %%
# operators 
# multiplication *

# %%
10*3  # 10+10+10 performed internally
# Out:
# 30

# %%
"abc"*3    #abc+abc+abc performed internally
# Out:
# 'abcabcabc'

# %%
# division

# %%
#1)true division /normal division 
512/12
# Out:
# 42.666666666666664

# %%
123.45/2
# Out:
# 61.725

# %%
(45+12j)/2
# Out:
# (22.5+6j)

# %%
True/2
# Out:
# 0.5

# %%
True/True
# Out:
# 1.0

# %%
False/True
# Out:
# 0.0

# %%
True/False   #1/0 goes to infinity i.e. zero division error
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
"abc"/1      # not supported for string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 "abc"/1      # not supported for string
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
[1,2,3]/2 #not supported
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 [1,2,3]/2 #not supported
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'

# %%
(1,2,3)/5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 (1,2,3)/5
#
# TypeError: unsupported operand type(s) for /: 'tuple' and 'int'

# %%
#2)floor division 
512//12
# Out:
# 42

# %%
(12+20j)//2 # complex does not support floor div
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 (12+20j)//2
#
# TypeError: unsupported operand type(s) for //: 'complex' and 'int'

# %%
#3)modulous  gives reminder of the division

# %%
100%3
# Out:
# 1

# %%
(12+12j)%2  # complex does not support modelous operation
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 (12+12j)%2  # complex does not support modelous operation
#
# TypeError: unsupported operand type(s) for %: 'complex' and 'int'

# %%
True*2
# Out:
# 2

# %%
# POWER OPERATOR

# %%
11**2
# Out:
# 121

# %%
11.11**2
# Out:
# 123.43209999999999

# %%
11J**2
# Out:
# (-121+0j)

# %%
True**2
# Out:
# 1

# %%
False**3
# Out:
# 0

# %%
"abc"**3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 "abc"**3
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
[1,2,3,4]**2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 [1,2,3,4]**2
#
# TypeError: unsupported operand type(s) for ** or pow(): 'list' and 'int'

# %%
(1,23,4)**8
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 (1,23,4)**8
#
# TypeError: unsupported operand type(s) for ** or pow(): 'tuple' and 'int'

# %%
{1,23,4}**5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 {1,23,4}**5
#
# TypeError: unsupported operand type(s) for ** or pow(): 'set' and 'int'

# %%
{1:2,3:'hi'}**4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 {1:2,3:'hi'}**4
#
# TypeError: unsupported operand type(s) for ** or pow(): 'dict' and 'int'

# %%
# 2 logical operators

# %%
#a) and

# %%
11 and 12
# Out:
# 12

# %%
12 and 0
# Out:
# 0

# %%
0 and 34
# Out:
# 0

# %%
'abc' and 45
# Out:
# 45

# %%
'' and 56
# Out:
# ''

# %%
[1,23,4] and [4,5]
# Out:
# [4, 5]

# %%
'abc' and 0 and 56
# Out:
# 0

# %%
'abc' and 11 and [12,34,5]
# Out:
# [12, 34, 5]

# %%
(4,5) and 0
# Out:
# 0

# %%
(23,4,56,7) and (125,567,9,5)
# Out:
# (125, 567, 9, 5)

# %%
#b) or operator

# %%
0 or 1
# Out:
# 1

# %%
1 or 45
# Out:
# 1

# %%
13431 or 0
# Out:
# 13431

# %%
[234,456] or 0
# Out:
# [234, 456]

# %%
[23,456,78,4] or []
# Out:
# [23, 456, 78, 4]

# %%
[] or [123,456,789,87]
# Out:
# [123, 456, 789, 87]

# %%
[] or ()
# Out:
# ()

# %%
#3 Assignment operators

# %%
# syntax :  var_name = value

# %%
a=10

# %%
#Argumented assignment operator

# %%
a%=10

# %%
a=12

# %%
a+=a**a

# %%
a
# Out:
# 8916100448268
