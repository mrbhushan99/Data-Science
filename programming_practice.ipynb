# %%
#wap to check weater given number is divisible by 3 ,
# if divisible by 3 then add 5 ,
# or else if divisible by 7 then print hello ,
# or else if divisible by 8 then print python
# otherwise print "Not done"

# %%
num = int(input("enter any number"))

if num % 3 ==0 :
    print("adding 5 to number")
    print(num+5)
elif num%7 ==0 :
    print("hello")
elif num % 8 == 0 :
    print("python")
else:
    print("not done")
# Out:
# hello

# %%
""" wap to check weather
perticular character if uppercase or
lowercase or 
digit or 
any special cahracter """
# Out:
# ' wap to check weather\nperticular character if uppercase or lowercase or digit or any special cahracter '

# %%
input_value = input ("enter any input")

if "A"<= input_value <="Z":
    print("upper CASE VALUE")
elif "a" <= input_value <="z":
    print("lowercase value")
elif "0" <= input_value <= "9":
    print("Digit")
else :
    print("special character")
# Out:
# lowercase value

# %%
''' you are given a 4 digit number 
first,compute the outer_digit_sum =first_digit + last_digit
and
inner digit product = second_digit +third digit

'''
# Out:
# ' you are given a 4 digit number \nfirst,compute the outer_digit_sum =first_digit + last_digit\nand\ninner digit product = second_digit +third digit\n\n'

# %%
num = int (input("enter any 4 digit number "))

forth_num = num%10
third_num = (num//10)%10 
second_num = (num//100)%10 # or (num//10)//10
first_num = num//1000 # or ((num//10)//10)//10

# %%
first_num
# Out:
# 1

# %%
second_num
# Out:
# 2

# %%
third_num
# Out:
# 3

# %%
forth_num
# Out:
# 4

# %%
outer_digit_sum = first_num + forth_num
inner_digit_product = second_num * third_num

# %%
if outer_digit_sum >inner_digit_product :
    print("OUTER DOMINATES")
elif outer_digit_sum < inner_digit_product :
    print("INNER DOMINATES")
else :
    print("balenced region")
# Out:
# INNER DOMINATES

# %%
# second decision chain 
combined_metxic = outer_digit_sum +inner_digit_product

perfect_threshold = 2 * (first_num + second_num + third_num + forth_num)
rising_threshold = first_num * forth_num

# %%
if num == perfect_threshold :
    print("perfect_threshold")
elif num > rising_threshold:
    print("rising zone")
elif num < rising_threshold:
    print("declining zone")
else :
    print("stagnant value")
# Out:
# rising zone

# %%
''' 
wap to check weather perticular character is 
uppercase ,lovercase , digits , special character .
if it is  uppercase  then print its respective lowercase ,
if it is lowercase then print its resptive uppercase char
otherwise keep it as it is  
'''
# Out:
# ' \nwap to check weather perticular character is \nuppercase ,lovercase , digits , special character .\nif it is  uppercase  then print its respective lowercase ,\nif it is lowercase then print its resptive uppercase char\notherwise keep it as it is  \n'

# %%
input_value = input ("enter any input")

if "A"<= input_value <="Z":
    print(chr(ord(input_value)+32))
    print(input_value.upper())
elif "a" <= input_value <="z":
    print(chr(ord(input_value)-32))
    print(input_value.lower())
elif "0" <= input_value <= "9":
    print(input_value)
else :
    print(input_value)
# Out:
# A
# a
