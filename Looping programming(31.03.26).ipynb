# %%
#wap to reverse a string without using slicing 
a= 'Bhushan'
reverse = ''
for i in a:
    reverse= i + reverse 
print(reverse)
# Out:
# nahsuhB

# %%
# to extract all the lowercase characters in a string onlu if the ascii value is even 
str = "Hii My Name is Bhushan"
# a =97 
for i in str:
    if ord(i)%2==0:
        if i in range(97,123):
            print(i)

# %%
ord("z")
# Out:
# 122

# %%
# to check weather the last digit of an integer iss even or not

# %%
# to extract all the key valye pairs from the disconary only if the keys are of 
# string datatype and values are integers

# %%
# to extract kay value pairs from the dictonary only if noth keys and values are exactly same

# %%
# to extract all the non default values from a list

# %%
# to check weather the list is homogenous or not

# %%
# to replace the space by * present in a string

# %%
# to extract all the string values present in a list only if the string is palendrone

# %%
# to extract all the odd numbers present at even index in a given list

# %%
# list ip odd num element chi sum , count  in integer and average in float

# %%
# NQT simple leverl practice 
#num_count = int(input("enter how many nyumbers are u going to enter in list"))
val = eval(input("enter value"))
lst1234567 = list(val)
#num_count = len(l)
sum =0
count=0
for i in lst1234567:
    if i%2==1:
        sum+=i
        count+=1
        
average = sum/count
print(int(sum),int(count),average)
# i = 0
# count=0
# while num_count>0:
    
#     num_count -=1 
#     list.append(val)
# odd_index_sum = 0  
# for j in range (len(list)):
#     # 
#     if j%2 == 1:
#         odd_index_sum += list[j]
#         count+=1
# average = odd_index_sum/count
# print(f"odd index sum {odd_index_sum} count is{count}, avg is{average:.2f)
# Out:
# 9 3 3.0
