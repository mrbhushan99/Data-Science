# %%
'''A boy is about to say something risky during a conversation.
His risk score is calculated by:
Risk = (message_length × 2) + (previous_mistakes × 3) − (sweet_words × 4) + (confidence_level × 1).
Take inputs for all values along with boy’s name.
If Risk > 30, print that he must stay silent immediately.
If Risk > 50, print that he must apologize before speaking.
Use only simple if statements to print whichever messages fit the conditions.'''
# Out:
# 'A boy is about to say something risky during a conversation.\nHis risk score is calculated by:\nRisk = (message_length × 2) + (previous_mistakes × 3) − (sweet_words × 4) + (confidence_level × 1).\nTake inputs for all values along with boy’s name.\nIf Risk > 30, print that he must stay silent immediately.\nIf Risk > 50, print that he must apologize before speaking.\nUse only simple if statements to print whichever messages fit the conditions.'

# %%
conversation = ''' asdfghjkl'''
name = input("Enter name ")
message = input("give your message")
previous_mistakes = int(input('enter previous mistakes'))
sweet_words = int(input('how many sweet words which you have used'))
confidence_level = int(input("what is the confidence level"))
message_length = len(message)



Risk = (message_length * 2) + (previous_mistakes * 3) - (sweet_words * 4) + (confidence_level * 1)
Risk
# Out:
# 120

# %%
if Risk > 30 :
    print("he must stay silent immediately.")
if Risk > 50 :
    print("he must apologize before speaking.")
# Out:
# he must stay silent immediately.
# he must apologize before speaking.

# %%
# Q 2 
''' 2. Girl’s Anger Temperature Predictor
A girl calculates her anger level based on:
Anger_Temp = (ignored_calls × 5) + (seen_but_no_reply × 7) − (his_effort × 3) + (mood_factor × 2).
Take her name and all numeric values.
If Anger_Temp > 40, print that volcano mode is ON.
If Anger_Temp > 60, print that he must bring ice cream.
If Anger_Temp > 80, print that he should run.'''

# %%
name = input("enter your name")
ignored_calls = int(input("how many calls are ignored"))
seen_but_no_reply = int(input("how many times he seen message but do not replyed"))
his_effort =int( input("rate his efforts"))
mood_factor = int(input("rate you moood score"))

# %%
Anger_Temp =(ignored_calls * 5) + (seen_but_no_reply * 7) - (his_effort * 3) + (mood_factor * 2)

# %%
Anger_Temp
# Out:
# 674

# %%
if Anger_Temp > 40 :
    print("volcano mode is ON.")
if Anger_Temp > 60:
    print("must bring ice cream.")
if Anger_Temp > 80 :
    print("he should run.")
# Out:
# volcano mode is ON.
# must bring ice cream.
# he should run.

# %%
'''3. Confusion Meter for Both Partners
Confusion = (mixed_signals × 4) + (miscommunication × 6) − (clarity × 5) + (overthinking × 3).
Take both names and all values.
If Confusion > 25, print that communication must be improved.
If Confusion > 50, print that assumptions must be avoided.
If Confusion > 75, print that a serious talk is needed.'''
# Out:
# '3. Confusion Meter for Both Partners\nConfusion = (mixed_signals × 4) + (miscommunication × 6) − (clarity × 5) + (overthinking × 3).\nTake both names and all values.\nIf Confusion > 25, print that communication must be improved.\nIf Confusion > 50, print that assumptions must be avoided.\nIf Confusion > 75, print that a serious talk is needed.'

# %%
p1 = input("enter your name")
p2 = input("enter your name")
mixed_signals =int(input("rate his mixed signals"))
miscommunication =int(input("rate his miscommunication level"))
clarity =int(input("rate his clarity level"))
overthinking =int(input("rate his overthinking level"))

# %%
Confusion = (mixed_signals * 4) + (miscommunication * 6) - (clarity * 5) + (overthinking * 3)
Confusion
# Out:
# 207

# %%
if Confusion > 25 :
    print("communication must be improved.")
if Confusion > 50 :
    print("assumptions must be avoided.")
if Confusion > 75 :
    print("serious talk is needed.")
# Out:
# communication must be improved.
# assumptions must be avoided.
# serious talk is needed.

# %%
'''4. Boy’s “Message Delay Excuse Strength” Calculation
Excuse_Strength = (reason_length × 5) − (reaction_time × 3) + (proof_strength × 4).
Take boy’s name and values.
If Excuse_Strength > 20, print that excuse may work.
If Excuse_Strength > 40, print that she might forgive.
If Excuse_Strength < 10, print that excuse will fail badly.'''
# Out:
# '4. Boy’s “Message Delay Excuse Strength” Calculation\nExcuse_Strength = (reason_length × 5) − (reaction_time × 3) + (proof_strength × 4).\nTake boy’s name and values.\nIf Excuse_Strength > 20, print that excuse may work.\nIf Excuse_Strength > 40, print that she might forgive.\nIf Excuse_Strength < 10, print that excuse will fail badly.'

# %%
name = input("enter your name")
reason_length = int(input("what is reson length"))
reaction_time = int (input("what is reson time"))
proof_strength = int(input("your proof of strength "))

# %%
Excuse_Strength = (reason_length * 5) - (reaction_time * 3) + (proof_strength * 4)

if Excuse_Strength > 20 :
    print("excause may work")
if Excuse_Strength > 40 :
    print("she might forgivre")
if Excuse_Strength > 10 :
    print("excause will fail badly")
# Out:
# excause may work
# she might forgivre
# excause will fail badly

# %%
'''5. Girl’s “Emotional Rollercoaster Index”
ERI = (memories × 3) + (latest_chat_analysis × 4) − (positivity × 2) + (overthinking × 6).
Take inputs.
If ERI > 30, print mood unstable.
If ERI > 60, print sensitive zone active.
If ERI > 90, print handle with care.'''
# Out:
# 9

# %%
name = input ("enter your name")
memories = int(input("how many memories you have aboute your relationship"))
latest_chat_analysis = int(input('rate your chat analysis'))
positivity = int(input("rate positivity"))
overthinking = int(input ("rate overthinking level "))

# %%
ERI = (memories * 3) + (latest_chat_analysis * 4) * (positivity * 2) + (overthinking * 6)

if ERI > 30 :
    print("mood unstable.")
if ERI > 60 :
    print("sensitive zone active.")
if ERI > 90:
    print("handle with care")
# Out:
# mood unstable.
# sensitive zone active.
# handle with care

# %%
'''6. Social Media Stalking Intensity Score
Stalking_Intensity = (profile_visits × 5) + (likes_checked × 4) + (comments_analyzed × 3) − (self_control ×
6).
Take name and numbers.
If Stalking_Intensity > 40, print mild stalking detected.
If Stalking_Intensity > 70, print heavy stalking detected.
If Stalking_Intensity > 90, print extreme stalking mode.'''
# Out:
# '6. Social Media Stalking Intensity Score\nStalking_Intensity = (profile_visits × 5) + (likes_checked × 4) + (comments_analyzed × 3) − (self_control ×\n6).\nTake name and numbers.\nIf Stalking_Intensity > 40, print mild stalking detected.\nIf Stalking_Intensity > 70, print heavy stalking detected.\nIf Stalking_Intensity > 90, print extreme stalking mode.'

# %%
name = input("enter name")
profile_visits = int(input("how many times you visit your profile"))
likes_checked = int(input("how many times you check your likes"))
comments_analyzed = int(input("howw many comments you analyse"))
self_control = int(input("rank your self control"))

# %%
Stalking_Intensity = (profile_visits * 5) + (likes_checked * 4) + (comments_analyzed * 3) - (self_control *6)

# %%
if Stalking_Intensity>40:
    print("mild stalking detected")
if Stalking_Intensity>70:
    print("heavy stalking detected.")
if Stalking_Intensity>90:
    print("extreme stalking mode.")
# Out:
# mild stalking detected
# heavy stalking detected.
# extreme stalking mode.

# %%
'''7. Boy’s Budget Damage After a Surprise Plan
Damage = (gifts × 8) + (travel_cost × 5) + (food × 3) − (discounts × 2).
Take input.
If Damage > 1000, print pocket dangerously damaged.
If Damage > 2000, print savings gone.
If Damage > 3000, print financial funeral scheduled.'''
# Out:
# '7. Boy’s Budget Damage After a Surprise Plan\nDamage = (gifts × 8) + (travel_cost × 5) + (food × 3) − (discounts × 2).\nTake input.\nIf Damage > 1000, print pocket dangerously damaged.\nIf Damage > 2000, print savings gone.\nIf Damage > 3000, print financial funeral scheduled.'

# %%
gifts = int(input("how many gifts you have given"))
travel_cost = int(input("What is your travel expence"))
food = int(input("What is your food expence"))
discounts = int(input("how many times you get discount"))

# %%
Damage = (gifts * 8) + (travel_cost * 5) + (food * 3) -  (discounts * 2)

if Damage >1000:
    print("pocket dangerously damaged.")
if Damage >2000:
    print("savings gone.")
if Damage >3000:
    print("financial funeral scheduled.")
# Out:
# pocket dangerously damaged.
# savings gone.
# financial funeral scheduled.

# %%
'''8. Girl’s Suspicion Detector Over Simple Things
Suspicion = (seen_but_no_reply × 4) + (typing_then_stopping × 6) + (reaction_time × 3) − (trust_level × 5).
Take inputs.
If Suspicion > 20, print that she starts doubting.
If Suspicion > 50, print heavy overthinking begins.
If Suspicion > 80, print investigation mode activated.'''
# Out:
# '8. Girl’s Suspicion Detector Over Simple Things\nSuspicion = (seen_but_no_reply × 4) + (typing_then_stopping × 6) + (reaction_time × 3) − (trust_level × 5).\nTake inputs.\nIf Suspicion > 20, print that she starts doubting.\nIf Suspicion > 50, print heavy overthinking begins.\nIf Suspicion > 80, print investigation mode activated.'

# %%
seen_but_no_reply = int(input("how many times seen msg but no reply"))
typing_then_stopping = int(input("how many times he is typing msg but stopping"))
reaction_time = int(input("what is his reaction time"))
trust_level = int(input("rate trust level"))

Suspicion = (seen_but_no_reply * 4) + (typing_then_stopping * 6) + (reaction_time * 3) - (trust_level * 5)

if Suspicion>20:
    print("she starts doubting.")
if Suspicion>50:
    print("heavy overthinking begins.")
if Suspicion>80:
    print("investigation mode activated.")
# Out:
# she starts doubting.

# %%
'''9. Relationship Stress Load Index
Stress = (arguments × 7) + (ignored_texts × 5) + (misunderstanding × 8) − (good_memories × 4).
Take names and values.
If Stress > 40, print relationship under pressure.
If Stress > 80, print danger zone.
If Stress > 120, print immediate action needed.'''
# Out:
# '9. Relationship Stress Load Index\nStress = (arguments × 7) + (ignored_texts × 5) + (misunderstanding × 8) − (good_memories × 4).\nTake names and values.\nIf Stress > 40, print relationship under pressure.\nIf Stress > 80, print danger zone.\nIf Stress > 120, print immediate action needed.'

# %%
name = input("enter your name")
arguments = int(input("how many times you both have argument"))
ignored_texts = int(input("how many times he ignored your text"))
misunderstanding = int(input("how many times misunderstanding is happened"))
good_memories = int(input("how many good memories you have"))

Stress = (arguments * 7) + (ignored_texts * 5) + (misunderstanding * 8) - (good_memories * 4)

if Stress > 40:
    print("relationship under pressure")
if Stress > 80:
    print("danger zone")
if Stress > 40:
    print("Immediate action needed")
# Out:
# relationship under pressure
# Immediate action needed

# %%
'''10. Boy’s “How Much Trouble Am I In?” Score
Trouble = (late_minutes × 6) + (forgotten_things × 9) − (apology_effort × 5).
Take input.
If Trouble > 30, print he is slightly in trouble.
If Trouble > 60, print he is officially in trouble.
If Trouble > 90, print he is deeply doomed'''
# Out:
# '10. Boy’s “How Much Trouble Am I In?” Score\nTrouble = (late_minutes × 6) + (forgotten_things × 9) − (apology_effort × 5).\nTake input.\nIf Trouble > 30, print he is slightly in trouble.\nIf Trouble > 60, print he is officially in trouble.\nIf Trouble > 90, print he is deeply doomed'

# %%
late_minutes = int(input("how much you are late "))
forgotten_things = int(input("how much things you forget"))
apology_effort = int(input("what is your apology effort"))

Trouble = (late_minutes * 6) + (forgotten_things * 9) - (apology_effort * 5)

if Trouble > 30:
    print("slightly in trouble.")
if Trouble > 60:
    print("officially in trouble.")
if Trouble > 90:
    print("he is deeply doomed")
# Out:
# slightly in trouble.
# officially in trouble.
# he is deeply doomed

# %%
'''11. WAP to compute “Reverse Dominance Check” of a 4-digit number
Take a 4-digit number.
Reverse it using arithmetic.
If the reverse > original number, print “reverse dominates.”
If the reverse < original number, print “original dominates.”
If both equal, print “balanced value.”
Use only simple if statements to show whichever conditions match.'''
# Out:
# '11. WAP to compute “Reverse Dominance Check” of a 4-digit number\nTake a 4-digit number.\nReverse it using arithmetic.\nIf the reverse > original number, print “reverse dominates.”\nIf the reverse < original number, print “original dominates.”\nIf both equal, print “balanced value.”\nUse only simple if statements to show whichever conditions match.'

# %%
num = int(input("enter 4 digit number"))
forth = num%10
third = (num//10)%10
second = (num//100)%10
first = (num//1000)%10

# %%
forth
# Out:
# 4

# %%
second
# Out:
# 2

# %%
first
# Out:
# 1

# %%
third
# Out:
# 3

# %%
reverse = forth*1000 + third*100 + second*10 + first
reverse
# Out:
# 4321

# %%
if reverse > num:
    print("reverse dominates")
if reverse < num:
    print("original dominates")
# Out:
# reverse dominates

# %%
'''12. WAP to check if the sum of even digits of a 5-digit number crosses danger limit
Extract digits manually.
Compute sum_even = d2 + d4.
If sum_even > 10, print danger zone.
If sum_even > 15, print high danger.
If sum_even > 20, print extreme danger.'''
# Out:
# '12. WAP to check if the sum of even digits of a 5-digit number crosses danger limit\nExtract digits manually.\nCompute sum_even = d2 + d4.\nIf sum_even > 10, print danger zone.\nIf sum_even > 15, print high danger.\nIf sum_even > 20, print extreme danger.'

# %%
num = int (input("enter 5 digit number"))
d2 = (num//1000)%10
d4 = (num//10)%10

# %%
d2
# Out:
# 7

# %%
sum_even = d2 + d4

# %%
if sum_even > 10 :
    print("danger zone")
if sum_even > 15 :
    print("high danger")
if sum_even > 20 :
    print("Extreme danger")
# Out:
# danger zone
# high danger

# %%
'''13. WAP to compare product of first two digits with product of last two digits of a 4-
digit number
Extract digits.
Compute p1 = d1 × d2.
Compute p2 = d3 × d4.
If p1 > p2, print left stronger.
If p2 > p1, print right stronger.
If equal, print equally strong.'''
# Out:
# '13. WAP to compare product of first two digits with product of last two digits of a 4-\ndigit number\nExtract digits.\nCompute p1 = d1 × d2.\nCompute p2 = d3 × d4.\nIf p1 > p2, print left stronger.\nIf p2 > p1, print right stronger.\nIf equal, print equally strong.'

# %%
num = int(input("enter 4 digit number"))
d4 = num%10
d3 = (num//10)%10
d2 = (num//100)%10
d1 = (num//1000)%10

p1 = d1 * d2
p2 = d3 * d4

if p1 > p2 :
    print("left stronger")
elif p2> p1 :
    print("right stronger")
else:
    print("equally strong")
# Out:
# right stronger

# %%
"""14. WAP to compute “Digit Stability Score” of a 5-digit number
Stability = (d1 × 2) + (d2 × 3) − (d3 × 1) + (d4 × 4) − (d5 × 2).
If Stability > 10, print mildly stable.
If Stability > 30, print very stable.
If Stability > 50, print extremely stable."""
# Out:
# '14. WAP to compute “Digit Stability Score” of a 5-digit number\nStability = (d1 × 2) + (d2 × 3) − (d3 × 1) + (d4 × 4) − (d5 × 2).\nIf Stability > 10, print mildly stable.\nIf Stability > 30, print very stable.\nIf Stability > 50, print extremely stable.'

# %%
num = int(input("enter 4 digit number"))
d5 = num%10
d4 = (num//10)%10
d3 = (num//100)%10
d2 = (num//1000)%10
d1 = (num//10000)%10

Stability = (d1 * 2) + (d2 * 3) - (d3 * 1) + (d4 * 4) - (d5 * 2)
