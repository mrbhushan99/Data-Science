# %%
#to print all the characters present at even index of a string 
string = input("enter any string")
i=1
while i<=len(string):
    print(string[i])
    i+=2
# Out:
# b
# d
# f

# %%
#to extract all the lowercase characters present in a string
ch = input("enter string ")
i= 0 
while i< len(ch):
    if 97 <= ord(ch[i]) <=122:
        print(ch[i])
    i+=1
# Out:
# a
# a
# c
# d
# e

# %%
ord('z')

chr(98)
# Out:
# 'b'

# %%
# to extract all the vovel present in a string 
string = input("enter the string")
i= 0
while i<len(string):
    if string[i] in "AEIOUaeiou":
        print(string[i])
    i+=1
# Out:
# a
# e

# %%
# to print factors of integer number 
num = int(input("enter number"))
i = 1
while i<1000:
    if num%i == 0 :
        print(i)
    i+=1
# Out:
# 1
# 3

# %%
# print reverse of a integer without using typecasting

num = int(input("enter number"))
length = int(input("enter how many digits number it is"))
i = 1:
while i<=length:  
    last = num%10
    third = (num//10)%10
    second = (num//100)%10
    first = (num//1000)%10

print(last*1000 + third*100 +second*10 + first)
# Out:
# 4321

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 len(num)
#
# TypeError: object of type 'int' has no len()

# %%
# Out:
# 4
