# %%
# check the given points are liying in which quadrant 
list =[12,3]
list[0] = int(input("enter first point (x co -ordinate)"))
list[1] = int(input("Enter second point(y-co - ordinate)"))

if list[0] > 0 and list[1] >0 :
    print("First Quadrant")
elif list[0] < 0 and list[1] >0 :
    print("second Quadrant")
elif list[0] < 0 and list[1] <0 :
    print("Third  Quadrant")
elif list[0] > 0 and list[1] < 0 :
    print("forth Quadrant")
# Out:
# Third  Quadrant

# %%
# find the gratest of 3 numbers 
n1= int(input("Enter First Number"))
n2= int(input("Enter Second Number"))
n3= int(input("Enter Third Number"))

if n1>n2:
    if n1>n3:
        print(n1," is biggest number")
elif n2>n1:
    if n2>n3:
        print(n3,"is biggest number")
elif n3>n2:
    if n3>n1:
        print(n3,"is gratest number")
# Out:
# 55  is biggest number

# %%
# wap to print fizz if the given number is multiple of 3 
# print buzz  if the give number is multiple of 5 
# and print fizzubzz if the number is multiple of both 3 and 5 

num = int(input("enter num"))
if num %3 ==0 and num%5 == 0:
    print("fizzubzz")
elif num%3 ==0:
    print("fizz")
elif num%5 == 0:
    print("buzz")
# Out:
# fizz
# fizzubzz

# %%
#wap to check weather the relation between 2 numbers

# %%
num1 = int (input("enter 1 st num"))
num2 = int(input("enter second number"))

if num1 == num2:
    print("both are equal")
elif num1 > num2:
    print("num1 is big")
else:
    print("num 2 is big")
# Out:
# num 2 is big

# %%
# check weather given i/p is vovel or not also handle invalid input

# %%
c= input("enter character")
if "A"<=c<="Z" or 'a'<=c<='z':
    if c in "AEIOUaeiou":
        print("vovel")
    else:
        print("consonant")
else:
    print("its not an alphabet")
# Out:
# its not an alphabet

# %%
#wap to login into the instagram with valid username and password 
#(enter pass only if the username is valid
username = "bhushan99"
password ="123@abc"
Entered_user_id = input("enter your instagram id ")
if Entered_user_id == username:
    Entered_pass = input("enter password")
    if password == Entered_pass:
        print("login successful")
    else:
        print("invalid password")
else:
    print("enter valid username")
# Out:
# login successful

# %%
#wap to print middle value of a list only if .it is string
list=  []
size = int(input("enter size of list"))
for i in range(0,size):
    list[i] = input(f"enter value {i} in list")
if len(list)%2 ==1:
    if list[len(list//2 + 1 )] ==str:
        print(list[len(list//2 + 1 )])

# %%
# wap to print the reversed string only if it is starting with vovel enging with consonant
# and having middle value

# %%
# prepaer stone paper sissors game
