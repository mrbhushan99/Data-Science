# %%
# General copy

# %%
a=[1,2,[3,4]]
b=a

# %%
b
# Out:
# [1, 2, [3, 4]]

# %%
a[1]=5

# %%
b
# Out:
# [1, 5, [3, 4]]

# %%
a[2][1]=6

# %%
a
# Out:
# [1, 5, [3, 6]]

# %%
b
# Out:
# [1, 5, [3, 6]]

# %%
id(a)
id(b)
# Out:
# 1846553624000

# %%
#Python tutor visulize .com see it

# %%
# shallow copy

# %%
c=[7,8,[9,10]]
d=c.copy()

# %%
d
# Out:
# [7, 8, [9, 10]]

# %%
c[1]=11

# %%
c
# Out:
# [7, 11, [9, 10]]

# %%
d
# Out:
# [7, 8, [9, 10]]

# %%
c[2][1]=55

# %%
c
# Out:
# [7, 11, [9, 55]]

# %%
d # changes in c are reflecting in d that is nested part
# Out:
# [7, 8, [9, 55]]

# %%
id(c)
# Out:
# 1846580118272

# %%
id(d)
# Out:
# 1846580096512

# %%
#Deep copy

# %%
a=[1,2,[3,4]]

# %%
import copy
b=copy.deepcopy(a)

# %%
a
# Out:
# [1, 2, [3, 4]]

# %%
b
# Out:
# [1, 2, [3, 4]]

# %%
a[1]=22

# %%
a
# Out:
# [1, 22, [3, 4]]

# %%
b
# Out:
# [1, 2, [3, 4]]

# %%
a[2][1]=99

# %%
a
# Out:
# [1, 22, [3, 99]]

# %%
b # changes in a are not happening in b
# Out:
# [1, 2, [3, 4]]

# %%
id(a)
# Out:
# 1846580222912

# %%
id(b)
# Out:
# 1846580283968

# %%
id(a[2]) # shars a different memory
# Out:
# 1846580281536

# %%
id(b[2]) # shares a different memory
# Out:
# 1846580094784
