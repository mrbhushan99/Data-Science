# %%
class BhushanUkarande:
    def __init__(self):
        self.name = "Bhushan Ukarande"
        self.role = "Data Scientist"
        self.location = "All over the World 🌍"
        self.origin = "India 🇮🇳"
        
    def get_expertise(self):
        return {
            "languages": ["Python", "SQL"],
            "ML_Algorithms": ["Decision tree", "KNN", "Random forest","Etc."],
            "ai_tools": ["LangChain", "Guardrails"],
            "databases": ["SQL"],
            "passion": ["GYM", "Music ", "Data ", "Racing "]
        }
    
    def current_focus(self):
        return [
            "Building intelligent systems",
            "Learning ML",
            "Making impactful decision from data",
            "Help myself to  master data science"
        ]
    
    def life_motto(self):
        return "Help Orgnizations to automate decision making,One Beard Stroke at a Time!"

# Initialize
Bhushan = BhushanUkarande()
print(Bhushan.get_expertise())
# Out:
# {'languages': ['Python', 'SQL'], 'ML_Algorithms': ['Decision tree', 'KNN', 'Random forest', 'Etc.'], 'ai_tools': ['LangChain', 'Guardrails'], 'databases': ['SQL'], 'passion': ['GYM', 'Music ', 'Data ', 'Racing ']}
