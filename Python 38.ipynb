# %%
import pandas as pd

data = {
    "Marks": [80, 75, 90, 85]
}

df = pd.DataFrame(data)

print("Average Marks:", df["Marks"].mean())
# Out:
# Average Marks: 82.5

# %%
df = pd.read_csv("D:\All work\MY LEARNING\ALL datasets\combined_data_1.txt")

print(df)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\Bhushan\AppData\Local\Temp\ipykernel_2152\1931339836.py:1: SyntaxWarning: invalid escape sequence '\A'
#   df = pd.read_csv("D:\All work\MY LEARNING\ALL datasets\combined_data_1.txt")
#                      1:
# 1488844 3.0  2005-09-06
# 822109  5.0  2005-05-13
# 885013  4.0  2005-10-19
# 30878   4.0  2005-12-26
# 823519  3.0  2004-05-03
# ...                 ...
# 2591364 2.0  2005-02-16
# 1791000 2.0  2005-02-10
# 512536  5.0  2005-07-27
# 988963  3.0  2005-12-20
# 1704416 3.0  2004-06-02
#
# [24058262 rows x 1 columns]

# %%
data = {
    "Name": ["Ram", "Shyam"],
    "Marks": [80, 75]
}

df = pd.DataFrame(data)

df.to_csv("output.csv", index=False)
