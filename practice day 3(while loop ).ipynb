# %%
# to  find the sum of individuAL SUM OF NUMBERS
num = int((input("enter number")))
rev=0
while(num>0):
    digit = num % 10
    rev += digit 
    num=num//10
print(rev)
# Out:
# 10

# %%
# to check weather the given numberis perfect or not 
num = int(input("enter any number"))
i =1 
sum = 0
while (i<sum):
    if num%i == 0 :
        sum+=i
if sum == num:
    print("perfect number") 
else:
    print("not perfect number")     
    
    ## check it
# Out:
# not perfect number

# %%
# to run infinite loop until user enters corrects pass 
i= 0
username = "Bhushan@123"
password = 'Pass@123'
while(True):
    entered_U_N = input("enter username")
    Entered_pass = input("enter password")
    if entered_U_N==username and Entered_pass == password:
        print("login success....")
        break
# Out:
# login success....

# %%
# to remove duplicates from a list without converting it  into set 
list = [1,2,3,4,1,2,3]
i=0
list2 = []
while i<len(list):
    if list[i] not in list2:
        #list2.append(list[i]) # OR
        list2+=[list[i]]
    i+=1
print(list2)
# Out:
# [1, 2, 3, 4]

# %%
# to find the sum of all the odd numbers between the given range 
s_num = int(input("enter start num"))
e_num = int(input("enter end number"))
i=s_num
odd_num_sum=0
while i in range(s_num,(e_num+1)):
    if s_num%2==1:
        odd_num_sum += s_num
    s_num+=1
    i+=1
    
print(f"{odd_num_sum}")
# Out:
# 4
